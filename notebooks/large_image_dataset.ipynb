# %% [markdown]
# # Automation of Dataset Creation

# %% [markdown]
# To run this notebook, download `products_asos.csv` from [Kaggle](https://www.kaggle.com/datasets/trainingdatapro/asos-e-commerce-dataset-30845-products).

# %%
import os
import pandas as pd
import requests

# %%
# 1) Read in the CSV
df = pd.read_csv("products_asos.csv", on_bad_lines='skip')
df = df.dropna(subset=['images'])

# %%
df['images']
# Out:
# 0        ['https://images.asos-media.com/products/new-l...
# 1        ['https://images.asos-media.com/products/new-l...
# 2        ['https://images.asos-media.com/products/new-l...
# 3        ['https://images.asos-media.com/products/new-l...
# 4        ['https://images.asos-media.com/products/strad...
#                                ...
# 30840    ['https://images.asos-media.com/products/urban...
# 30841    ['https://images.asos-media.com/products/asos-...
# 30842    ['https://images.asos-media.com/products/asyou...
# 30843    ['https://images.asos-media.com/products/miss-...
# 30844    ['https://images.asos-media.com/products/other...
# Name: images, Length: 30827, dtype: object

# %%
df = df.drop_duplicates(subset=['images'])

# %%
df['images']
# Out:
# 0        ['https://images.asos-media.com/products/new-l...
# 4        ['https://images.asos-media.com/products/strad...
# 8        ['https://images.asos-media.com/products/jdy-o...
# 10       ['https://images.asos-media.com/products/nike-...
# 14       ['https://images.asos-media.com/products/asos-...
#                                ...
# 30840    ['https://images.asos-media.com/products/urban...
# 30841    ['https://images.asos-media.com/products/asos-...
# 30842    ['https://images.asos-media.com/products/asyou...
# 30843    ['https://images.asos-media.com/products/miss-...
# 30844    ['https://images.asos-media.com/products/other...
# Name: images, Length: 29972, dtype: object

# %%
# Take first 5000 rows for now
df = df.head(5000)

# %%
# Clean the 'images' column: remove brackets and quotes, extract the first URL
def clean_image_cell(cell):
    if pd.isna(cell):
        return None
    # Remove brackets and single/double quotes
    cleaned = cell.strip("[]").replace("'", "").replace('"', '')
    # Return the first URL (split on comma if needed)
    return cleaned.split(",")[0].strip()

df['images'] = df['images'].apply(clean_image_cell)

# %%
print(df['images'][0])
# Out:
# https://images.asos-media.com/products/new-look-trench-coat-in-camel/204351106-4?$n_1920w$&wid=1926&fit=constrain

# %%
for url in df['images'][0].split(","):
  print(url)
# Out:
# https://images.asos-media.com/products/new-look-trench-coat-in-camel/204351106-4?$n_1920w$&wid=1926&fit=constrain

# %%
# 2) Create a folder to hold the downloaded images
os.makedirs("asos_images", exist_ok=True)

# 3) Loop over each row's image URL in the 'images' column
index = 75 # currently have 74 images in dataset
for i, row in df.iterrows():
    image_url = row["images"]
    if pd.isna(image_url):
        # If there's no image URL, skip
        continue

    # 4) Download the image
    try:
        response = requests.get(image_url, timeout=10)
        response.raise_for_status()  # Raise an error if status != 200

        # 5) Save the image to disk
        filename = os.path.join("asos_images", f"{index}.png")
        with open(filename, "wb") as f:
            f.write(response.content)
        index += 1
    except Exception as e:
        print(f"Failed to download {image_url}: {e}")

# %%
print(index) # next index should start here
# Out:
# 5075

# %%
# !zip -r asos_images.zip asos_images

# %%
from google.colab import files
files.download("asos_images.zip")

# %% [markdown]
# ## Concatenating with original dataset

# %%
orig_df = pd.read_excel('dataset.xlsx', sheet_name='Sheet1')

# %%
orig_df = orig_df.drop(columns=['image','user','brand'])

# %%
orig_df
# Out:
#                                                  name  \
# 0                          Twill Wide-Leg Cargo Pants
# 1   Denim for all seasons, 3-length vintage Faded ...
# 2                       Mid-Rise Wide-Leg Cargo Pants
# 3                           Fine layered check blouse
# 4   Blena Heart Strap Button Lace Cropped Sleevele...
# ..                                                ...
# 68                                  Short tweed dress
# 69                           Floral sleeveless jumper
# 70                                   Belted wool coat
# 71                        Long Castleford Trench Coat
# 72                    The Effortless Pant™ - Crepette
#
#                                           description    price
# 0   A pair of twill pants featuring contrasting to...    24.49
# 1   Country of Origin : China(OEM)\nMaterial : 100...    25.68
# 2   A pair of twill pants featuring a mid-rise wai...    24.49
# 3   Country of Origin : China(OEM)\nMaterial : Cot...    33.53
# 4   Country of Origin : Korea/China(OEM)\nMaterial...    24.57
# ..                                                ...      ...
# 68  The studio has reinterpreted the Parisian offi...   445.00
# 69  For the new collection, the Maje studio celebr...   265.00
# 70  Long double-breasted coat in fine pure wool br...   875.00
# 71  A trench coat made in England from shower-resi...  2890.00
# 72  The original goes-with-everything trouser, the...   148.00
#
# [73 rows x 3 columns]

# %%
new_df = df[['name','description','price']]

# %%
new_df
# Out:
#                                                    name  \
# 0                         New Look trench coat in camel
# 4        Stradivarius double breasted wool coat in grey
# 8                    JDY oversized trench coat in stone
# 10                   Nike Running hooded jacket in pink
# 14    ASOS DESIGN Tall linen mix trench coat in natural
# ...                                                 ...
# 5528                    Mango high neck jumper in cream
# 5529  New Look ribbed crew neck knitted jumper in bu...
# 5530   Noisy May crew neck knitted jumper in dark green
# 5531   Wednesday's Girl longline cardigan in cable knit
# 5532  M Lounge stitchy rib high-neck jumper in fores...
#
#                                             description       price
# 0     [{'Product Details': 'Coats & Jackets by New L...       49.99
# 4     [{'Product Details': 'Coats & Jackets by Strad...       59.99
# 8     [{'Product Details': 'Coats & Jackets by JDYLo...       45.00
# 10    [{'Product Details': 'Coats & Jackets by Nike ...       84.95
# 14    [{'Product Details': 'Coats & Jackets by ASOS ...       75.00
# ...                                                 ...         ...
# 5528  [{'Product Details': 'Jumpers & Cardigans by M...       35.99
# 5529  [{'Product Details': 'Jumpers & Cardigans by N...       16.99
# 5530  [{'Product Details': 'Jumper by Noisy May Soft...  Now  16.80
# 5531  [{'Product Details': "Cardigans by Wednesday's...       28.00
# 5532  [{'Product Details': 'Jumper by M Lounge Cosy ...  Now  25.20
#
# [5000 rows x 3 columns]

# %%
df_combined = pd.concat([orig_df, new_df], ignore_index=True)

# %%
df_combined
# Out:
#                                                    name  \
# 0                            Twill Wide-Leg Cargo Pants
# 1     Denim for all seasons, 3-length vintage Faded ...
# 2                         Mid-Rise Wide-Leg Cargo Pants
# 3                             Fine layered check blouse
# 4     Blena Heart Strap Button Lace Cropped Sleevele...
# ...                                                 ...
# 5068                    Mango high neck jumper in cream
# 5069  New Look ribbed crew neck knitted jumper in bu...
# 5070   Noisy May crew neck knitted jumper in dark green
# 5071   Wednesday's Girl longline cardigan in cable knit
# 5072  M Lounge stitchy rib high-neck jumper in fores...
#
#                                             description       price
# 0     A pair of twill pants featuring contrasting to...       24.49
# 1     Country of Origin : China(OEM)\nMaterial : 100...       25.68
# 2     A pair of twill pants featuring a mid-rise wai...       24.49
# 3     Country of Origin : China(OEM)\nMaterial : Cot...       33.53
# 4     Country of Origin : Korea/China(OEM)\nMaterial...       24.57
# ...                                                 ...         ...
# 5068  [{'Product Details': 'Jumpers & Cardigans by M...       35.99
# 5069  [{'Product Details': 'Jumpers & Cardigans by N...       16.99
# 5070  [{'Product Details': 'Jumper by Noisy May Soft...  Now  16.80
# 5071  [{'Product Details': "Cardigans by Wednesday's...       28.00
# 5072  [{'Product Details': 'Jumper by M Lounge Cosy ...  Now  25.20
#
# [5073 rows x 3 columns]

# %%
df_combined.to_excel('5k_dataset.xlsx', index=False)

# %% [markdown]
# ## Adding men's clothing (do not use for now)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import os
import glob

# %%
folder_path = '/content/drive/My Drive/Penn Spring 2025/STAT 4830/men'
csv_files = glob.glob(os.path.join(folder_path, '*.csv'))

# %%
men_df = pd.DataFrame()
for file in csv_files:
    try:
        # Read the CSV file
        desired_cols = ['product_name', 'product_images', 'price', 'details']
        curr_df = pd.read_csv(file)
        curr_df.columns = curr_df.columns.str.strip().str.lower()
        curr_df = curr_df[desired_cols]
        # Append to the combined DataFrame
        men_df = pd.concat([men_df, curr_df], ignore_index=True)
    except ValueError as e:
        print(f"Skipping file {file} due to missing columns: {e}")

# %%
men_df = men_df.dropna()

# %%
men_df
# Out:
#                           product_name  \
# 0               100% LINEN SUIT BLAZER
# 1                  JACKET WITH POCKETS
# 2          100% LINEN PLEATED TROUSERS
# 3               KNIT COTTON POLO SHIRT
# 4                         OXFORD SHIRT
# ..                                 ...
# 936           CROPPED DENIM SWEATSHIRT
# 937  DENIM T-SHIRT WITH ABSTRACT PRINT
# 938        VINTAGE FADED DENIM T-SHIRT
# 939           TIE-DYE PRINT SWEATSHIRT
# 940               TIE-DYE DENIM HOODIE
#
#                                         product_images        price  \
# 0    [{'https://static.zara.net/photos///2023/I/0/2...  ₹ 11,990.00
# 1    [{'https://static.zara.net/photos///2023/I/0/2...   ₹ 7,590.00
# 2    [{'https://static.zara.net/photos///2023/I/0/2...   ₹ 5,990.00
# 3    [{'https://static.zara.net/photos///2023/I/0/2...   ₹ 3,290.00
# 4    [{'https://static.zara.net/photos///2023/I/0/2...   ₹ 4,990.00
# ..                                                 ...          ...
# 936  [{'https://static.zara.net/photos///2023/I/0/2...   ₹ 3,290.00
# 937  [{'https://static.zara.net/photos///2023/I/0/2...   ₹ 2,990.00
# 938  [{'https://static.zara.net/photos///2023/I/0/2...   ₹ 2,590.00
# 939  [{'https://static.zara.net/photos///2023/I/0/2...   ₹ 3,290.00
# 940  [{'https://static.zara.net/photos///2023/I/0/1...   ₹ 3,290.00
#
#                                                details
# 0    Regular-fit blazer made of linen. Notched lape...
# 1    Faded regular-fit collared jacket with long sl...
# 2    Regular fit trousers made of a linen fabric. w...
# 3    Round collar knit polo shirt in spun cotton fa...
# 4    Regular-fit shirt made of a textured cotton fa...
# ..                                                 ...
# 936  Oversize fit cropped faded sweatshirt featurin...
# 937  Lightweight denim T-shirt with a round necklin...
# 938  T-shirt made of lightweight denim. Featuring a...
# 939  Round neck sweatshirt with short sleeves and i...
# 940  Denim sweatshirt. Round neck and short sleeves...
#
# [939 rows x 4 columns]

# %%
men_df['product_images'][0]
# Out:
# "[{'https://static.zara.net/photos///2023/I/0/2/p/1564/102/506/2/w/489/1564102506_1_1_1.jpg?ts=1688573213489': 'Image 0 of 100% LINEN SUIT BLAZER from Zara'}, {'https://static.zara.net/photos///2023/I/0/2/p/1564/102/506/2/w/489/1564102506_2_1_1.jpg?ts=1688573213424': 'Image 1 of 100% LINEN SUIT BLAZER from Zara'}]"

# %%
import ast

def clean_image_cell(cell):
    if pd.isna(cell):
        return None
    try:
        # Convert stringified list of dicts to actual Python list
        image_list = ast.literal_eval(cell)
        if isinstance(image_list, list) and len(image_list) > 0:
            first_dict = image_list[0]
            if isinstance(first_dict, dict):
                return list(first_dict.keys())[0]
    except Exception as e:
        print(f"Failed to parse image cell: {cell[:100]}... Error: {e}")
    return None

men_df['product_images'] = men_df['product_images'].apply(clean_image_cell)
# Out:
# <ipython-input-50-269812f2a7c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   men_df['product_images'] = men_df['product_images'].apply(clean_image_cell)

# %%
men_df['product_images'][0]
# Out:
# 'https://static.zara.net/photos///2023/I/0/2/p/1564/102/506/2/w/489/1564102506_1_1_1.jpg?ts=1688573213489'

# %%
men_df = men_df.rename(columns={'product_name': 'name', 'product_images': 'images', 'details': 'description'})

# %%
df_combined = pd.concat([df_combined, men_df[['name','description','price']]], ignore_index=True)

# %%
df_combined
# Out:
#                                                    name  \
# 0                            Twill Wide-Leg Cargo Pants
# 1     Denim for all seasons, 3-length vintage Faded ...
# 2                         Mid-Rise Wide-Leg Cargo Pants
# 3                             Fine layered check blouse
# 4     Blena Heart Strap Button Lace Cropped Sleevele...
# ...                                                 ...
# 6007                           CROPPED DENIM SWEATSHIRT
# 6008                  DENIM T-SHIRT WITH ABSTRACT PRINT
# 6009                        VINTAGE FADED DENIM T-SHIRT
# 6010                           TIE-DYE PRINT SWEATSHIRT
# 6011                               TIE-DYE DENIM HOODIE
#
#                                             description       price
# 0     A pair of twill pants featuring contrasting to...       24.49
# 1     Country of Origin : China(OEM)\nMaterial : 100...       25.68
# 2     A pair of twill pants featuring a mid-rise wai...       24.49
# 3     Country of Origin : China(OEM)\nMaterial : Cot...       33.53
# 4     Country of Origin : Korea/China(OEM)\nMaterial...       24.57
# ...                                                 ...         ...
# 6007  Oversize fit cropped faded sweatshirt featurin...  ₹ 3,290.00
# 6008  Lightweight denim T-shirt with a round necklin...  ₹ 2,990.00
# 6009  T-shirt made of lightweight denim. Featuring a...  ₹ 2,590.00
# 6010  Round neck sweatshirt with short sleeves and i...  ₹ 3,290.00
# 6011  Denim sweatshirt. Round neck and short sleeves...  ₹ 3,290.00
#
# [6012 rows x 3 columns]

# %%
# Create a folder to hold the downloaded images
os.makedirs("zara_men_images4", exist_ok=True)
headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/115.0.0.0 Safari/537.36"
    )
}

# Loop over each row's image URL in the 'images' column
index = 5075 # currently have 5074 images in dataset
for i, row in men_df.iterrows():
    image_url = row["images"]
    if pd.isna(image_url):
        # If there's no image URL, skip
        continue

    # 4) Download the image
    try:
        response = requests.get(image_url, headers=headers, timeout=10)
        response.raise_for_status()  # Raise an error if status != 200

        # 5) Save the image to disk
        filename = os.path.join("zara_men_images", f"{index}.jpg")
        with open(filename, "wb") as f:
            f.write(response.content)
        index += 1
    except Exception as e:
        print(f"Failed to download {image_url}: {e}")
# Out:
# Failed to download https://static.zara.net/photos///2023/I/0/2/p